# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("House_price_pridiction.csv")

# %%
print(df.to_string())
# Out:
#       bedrooms  bathrooms  sqft_living  floors         price
# 0            3       1.50         1340     1.5  3.130000e+05
# 1            5       2.50         3650     2.0  2.384000e+06
# 2            3       2.00         1930     1.0  3.420000e+05
# 3            3       2.25         2000     1.0  4.200000e+05
# 4            4       2.50         1940     1.0  5.500000e+05
# 5            2       1.00          880     1.0  4.900000e+05
# 6            2       2.00         1350     1.0  3.350000e+05
# 7            4       2.50         2710     2.0  4.820000e+05
# 8            3       2.50         2430     1.0  4.525000e+05
# 9            4       2.00         1520     1.5  6.400000e+05
# 10           3       1.75         1710     1.0  4.630000e+05
# 11           4       2.50         2920     1.5  1.400000e+06
# 12           3       1.75         2330     1.0  5.885000e+05
# 13           3       1.00         1090     1.0  3.650000e+05
# ...

# %%
#plt.scatter(df['bedrooms'],df['price'])

# %%
#plt.scatter(df['bathrooms'],df['price'])

# %%
plt.scatter(df['sqft_living'],df['price'])

# %%
#plt.scatter(df['floors'],df['price'])

# %%
# X1 = df.iloc[:,0:1]
# X2 = df.iloc[:,1:2]
X3 = df.iloc[:,2:3]
# X4 = df.iloc[:,3:4]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
X3
# Out:
#       sqft_living
# 0            1340
# 1            3650
# 2            1930
# 3            2000
# 4            1940
# ...           ...
# 4595         1510
# 4596         1460
# 4597         3010
# 4598         2090
# 4599         1490
#
# [4600 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
# X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y,test_size=0.2,random_state=2)
# X2_train,X2_test,y2_train,y2_test = train_test_split(X2,y,test_size=0.2,random_state=2)
X3_train,X3_test,y3_train,y3_test = train_test_split(X3,y,test_size=0.2,random_state=2)
# X4_train,X4_test,y4_train,y4_test = train_test_split(X4,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
# lr.fit(X1_train,y_train)
# lr.fit(X2_train,y_train)
lr.fit(X3_train,y_train)
# lr.fit(X4_train,y_train)
# Out:
# LinearRegression()

# %%
X3_test
# Out:
#       sqft_living
# 4111         1460
# 1996         1560
# 2307         2340
# 3607         1110
# 1519         2798
# ...           ...
# 2516         2960
# 993          1990
# 3713         1620
# 4541         2210
# 3016         2200
#
# [920 rows x 1 columns]

# %%
# lr.predict(X1_test.iloc[0].values.reshape(1,1))

# %%
# lr.predict(X2_test.iloc[0].values.reshape(1,1))

# %%
 lr.predict(X3_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([369710.98462384])

# %%
# lr.predict(X4_test.iloc[0].values.reshape(1,1))

# %%
# y_pred1=lr.predict(X1_test)
# y_pred2=lr.predict(X2_test)
y_pred3=lr.predict(X3_test)
# y_pred4=lr.predict(X4_test)

# %%
plt.scatter(df['sqft_living'],df['price'])
plt.plot(X1_train.squeeze(),lr.predict(X1_train),color='red')
plt.xlabel('bedroom')
plt.ylabel('price')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - bedrooms
# Feature names seen at fit time, yet now missing:
# - sqft_living
#
#   warnings.warn(message, FutureWarning)
# Text(0, 0.5, 'price')

# %%
m= lr.coef_

# %%
b =lr.intercept_

# %%
# y = mx + b

y=m * 8.58 + b

# %%
from sklearn.metrics import mean_absolute_error
# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test,y_pred)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# Mean Absolute Error: 257115.33

# %%
from sklearn.metrics import mean_squared_error

# Calculate Mean Squared Error
mse = mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 863463101884.78
